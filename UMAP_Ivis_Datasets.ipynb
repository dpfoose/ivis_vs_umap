# %%
library(packrat)
packrat::init("~/mlbench")
library(mlbench)
# Out:
# Initializing packrat project in directory:
# - "~/mlbench"
# Initialization complete!

# %%
smiley <- mlbench.smiley(10000)
plot(smiley)
write.csv(smiley, file="/home/dfoose/notebooks/UMAP_Ivis/data/smiley.csv")
# Out:
# plot without title

# %%
loose_smiley <-mlbench.smiley(10000, 0.35, 0.35)
plot(loose_smiley)
write.csv(loose_smiley, file="/home/dfoose/notebooks/UMAP_Ivis/data/loose_smiley.csv")
# Out:
# plot without title

# %%
Cassini <- mlbench.cassini(10000)
plot(Cassini)
write.csv(Cassini, file='/home/dfoose/notebooks/UMAP_Ivis/data/cassini.csv')
# Out:
# plot without title

# %%
packrat::init("~/mlbench")
library(TENxPBMCData)
pbmc3k.sce <- TENxPBMCData(dataset = "pbmc3k")
pbmc3k.sce
# Out:
# Initializing packrat project in directory:
# - "~/mlbench"
# Initialization complete!
# Error in library(TENxPBMCData): there is no package called ‘TENxPBMCData’
# Traceback:
#
# 1. library(TENxPBMCData)

# %%
library(TENxPBMCData)
# Out:
# Error in library(TENxPBMCData): there is no package called ‘TENxPBMCData’
# Traceback:
#
# 1. library(TENxPBMCData)

# %%
install.packages("Seurat")
# Out:
# Installing package into ‘/home/dfoose/mlbench/packrat/lib/x86_64-pc-linux-gnu/3.6.1’
# (as ‘lib’ is unspecified)
# also installing the dependencies ‘lsei’, ‘stringr’, ‘bibtex’, ‘gbRd’, ‘stringi’, ‘lifecycle’, ‘gtools’, ‘gdata’, ‘caTools’, ‘colorspace’, ‘R.oo’, ‘R.methodsS3’, ‘sitmo’, ‘gtable’, ‘npsurv’, ‘globals’, ‘listenv’, ‘lazyeval’, ‘reshape2’, ‘viridisLite’, ‘withr’, ‘plyr’, ‘curl’, ‘zoo’, ‘Rdpack’, ‘base64enc’, ‘htmlwidgets’, ‘tidyr’, ‘hexbin’, ‘crosstalk’, ‘data.table’, ‘gplots’, ‘labeling’, ‘munsell’, ‘gridExtra’, ‘R.utils’, ‘FNN’, ‘RSpectra’, ‘RcppParallel’, ‘dqrng’, ‘ape’, ‘cowplot’, ‘fitdistrplus’, ‘future’, ‘future.apply’, ‘ggplot2’, ‘ggrepel’, ‘ggridges’, ‘httr’, ‘ica’, ‘igraph’, ‘irlba’, ‘leiden’, ‘lmtest’, ‘metap’, ‘pbapply’, ‘plotly’, ‘png’, ‘RANN’, ‘RColorBrewer’, ‘RcppAnnoy’, ‘reticulate’, ‘ROCR’, ‘rsvd’, ‘Rtsne’, ‘scales’, ‘sctransform’, ‘SDMTools’, ‘tsne’, ‘uwot’, ‘RcppEigen’, ‘RcppProgress’
#
# Warning message in install.packages("Seurat"):
# ...
